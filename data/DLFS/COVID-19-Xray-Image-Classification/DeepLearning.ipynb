# %%
#Importing required libraries.

from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator,load_img, img_to_array
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D,GlobalAveragePooling2D,Convolution2D
from keras.layers import Activation, Dropout, BatchNormalization, Flatten, Dense, AvgPool2D,MaxPool2D
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.optimizers import Adam, SGD, RMSprop

import tensorflow as tf

import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # **Importing dataset from google drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Connecting Data from Google Drive**

# %%
data_location = '/content/drive/MyDrive/DeepLearningPorject/data_set/check/Khela/train/covid'
IMAGE_SHAPE = (256, 256, 3)
BATCH_SIZE = 10
EPOCHS = 50
DATASET_SIZE = sum([len(files) for r, d, files in os.walk(data_location)])

# %%
DATASET_SIZE
# Out:
# 242

# %% [markdown]
# #We had very few covid-positive datas. So we did data augmentation to create new covid-positive datas by changing some attributes from existing datas

# %%
import keras
import cv2
import os
import glob
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
datagen = ImageDataGenerator(rotation_range =5,    
                         rescale=1./255, 
                         shear_range=0.2, 
                         zoom_range=0.3, 
                         horizontal_flip = True, 
                         fill_mode = 'nearest', 
                         data_format='channels_last', 
                         brightness_range=[0.2,1.0])


img_dir = "/content/drive/MyDrive/DeepLearningPorject/data_set_2/data_set/train/covid" # Enter Directory of all images 
data_path = os.path.join(img_dir,'*g')
files = glob.glob(data_path)
data = []
for f1 in files:
    img = cv2.imread(f1)
    data.append(img)

x = img_to_array(img)
x = x.reshape((1,) + x.shape)

i = 0
path, dirs, files = next(os.walk("/content/drive/MyDrive/DeepLearningPorject/data_set_2/data_set/train/covid"))
file_count = len(files) #to find number of files in folder

for batch in datagen.flow (x, batch_size=1, save_to_dir =r'/content/drive/MyDrive/DeepLearningPorject/data_set_2/data_set/train/covid',save_prefix="a",save_format='jpg'):
    i+=1
    if i==file_count:
      break

# %% [markdown]
# # **For deleting extra folder of Augmented images**

# %%
# import os

# filelist = [ f for f in os.listdir("/content/drive/MyDrive/DeepLearningPorject/data_set/train/new") if f.endswith(".jpg") ]
# for f in filelist:
#     os.remove(os.path.join("/content/drive/MyDrive/DeepLearningPorject/data_set/train/new", f))

# %%
#Fitting to CNN to the images

from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        rotation_range=40,
        brightness_range=[0.2,1.0],
        width_shift_range=0.2,
        height_shift_range=0.2,
        horizontal_flip=True,
        fill_mode = 'nearest')


test_datagen = ImageDataGenerator(rescale=1./255)

training_set = train_datagen.flow_from_directory(
        '/content/drive/MyDrive/DeepLearningPorject/data_set/check/Khela/train',
        target_size=(265,256),
        batch_size=32,
        class_mode='binary')

test_set = test_datagen.flow_from_directory(
        '/content/drive/MyDrive/DeepLearningPorject/data_set/check/Khela/test',
        target_size=(256, 256),
        batch_size=32,
        class_mode='binary')
# Out:
# Found 1236 images belonging to 2 classes.
# Found 1573 images belonging to 2 classes.

# %% [markdown]
# # **Initializing the Model**

# %%
classifier = Sequential()

#step 1 - Convolution
#creating the feature map by using feature detector from ınput image

classifier.add( Convolution2D(64,3,3, input_shape=(256,256,3), activation='relu'))
classifier.add(MaxPooling2D(pool_size = (2,2)))
# classifier.add(Dropout(0.25))

#second convolution and pooling steps.
classifier.add( Convolution2D(32,3,3, activation='relu'))
classifier.add(MaxPooling2D(pool_size = (2,2)))
# classifier.add(Dropout(0.25))


#step -3 Flattening
classifier.add(Flatten())

#step-4 Full connection step
classifier.add(Dense(256, activation = 'relu'))
classifier.add(Dense(1, activation = 'sigmoid'))
#binary outcome

# %% [markdown]
# # **Compiling the Model**

# %%
classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# # **Model summary**

# %%
classifier.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_38 (Conv2D)           (None, 85, 85, 64)        1792
# _________________________________________________________________
# max_pooling2d_35 (MaxPooling (None, 42, 42, 64)        0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 14, 14, 32)        18464
# _________________________________________________________________
# max_pooling2d_36 (MaxPooling (None, 7, 7, 32)          0
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 1568)              0
# _________________________________________________________________
# dense_26 (Dense)             (None, 256)               401664
# _________________________________________________________________
# dense_27 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 422,177
# Trainable params: 422,177
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # **Training Model**

# %%
steps_per_epoch = len(training_set)//BATCH_SIZE
validation_steps = len(test_set)//BATCH_SIZE # if you have test data


results = classifier.fit(training_set,
                    steps_per_epoch=steps_per_epoch,
                    epochs=100,
                    validation_data=test_set,
                    validation_steps=validation_steps,
                    workers=1)
print(len(training_set))
print(len(test_set))
# Out:
# Epoch 1/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.6511 - accuracy: 0.5339 - val_loss: 0.2349 - val_accuracy: 0.9312
# Epoch 2/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.4695 - accuracy: 0.8451 - val_loss: 0.2549 - val_accuracy: 0.9250
# Epoch 3/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.4229 - accuracy: 0.8646 - val_loss: 0.2157 - val_accuracy: 0.9438
# Epoch 4/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.5403 - accuracy: 0.7930 - val_loss: 0.2731 - val_accuracy: 0.9187
# Epoch 5/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.5425 - accuracy: 0.7591 - val_loss: 0.2780 - val_accuracy: 0.9187
# Epoch 6/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.5575 - accuracy: 0.7604 - val_loss: 0.2783 - val_accuracy: 0.9187
# Epoch 7/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.4282 - accuracy: 0.8385 - val_loss: 0.2338 - val_accuracy: 0.9312
# Epoch 8/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.4419 - accuracy: 0.8594 - val_loss: 0.2268 - val_accuracy: 0.9375
# Epoch 9/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.3944 - accuracy: 0.8477 - val_loss: 0.2247 - val_accuracy: 0.9438
# Epoch 10/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.5346 - accuracy: 0.7773 - val_loss: 0.2641 - val_accuracy: 0.9438
# Epoch 11/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.4366 - accuracy: 0.8659 - val_loss: 0.1863 - val_accuracy: 0.9500
# Epoch 12/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.5884 - accuracy: 0.7526 - val_loss: 0.2067 - val_accuracy: 0.9438
# Epoch 13/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.4267 - accuracy: 0.8451 - val_loss: 0.2458 - val_accuracy: 0.9250
# Epoch 14/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.2988 - accuracy: 0.9102 - val_loss: 0.2600 - val_accuracy: 0.9187
# Epoch 15/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.3948 - accuracy: 0.8633 - val_loss: 0.2884 - val_accuracy: 0.9062
# Epoch 16/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.4549 - accuracy: 0.8047 - val_loss: 0.2851 - val_accuracy: 0.9312
# Epoch 17/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.4437 - accuracy: 0.8504 - val_loss: 0.2652 - val_accuracy: 0.9563
# Epoch 18/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.4357 - accuracy: 0.8229 - val_loss: 0.1296 - val_accuracy: 0.9688
# Epoch 19/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.4073 - accuracy: 0.8151 - val_loss: 0.2007 - val_accuracy: 0.9563
# Epoch 20/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.4108 - accuracy: 0.8138 - val_loss: 0.2701 - val_accuracy: 0.9312
# Epoch 21/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.3714 - accuracy: 0.8424 - val_loss: 0.1516 - val_accuracy: 0.9563
# Epoch 22/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.3317 - accuracy: 0.8685 - val_loss: 0.1885 - val_accuracy: 0.9250
# Epoch 23/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.3758 - accuracy: 0.8034 - val_loss: 0.2295 - val_accuracy: 0.9312
# Epoch 24/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.3868 - accuracy: 0.8620 - val_loss: 0.2476 - val_accuracy: 0.9312
# Epoch 25/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.3710 - accuracy: 0.8268 - val_loss: 0.1352 - val_accuracy: 0.9688
# Epoch 26/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.3821 - accuracy: 0.8320 - val_loss: 0.2407 - val_accuracy: 0.9125
# Epoch 27/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.4587 - accuracy: 0.8203 - val_loss: 0.2872 - val_accuracy: 0.8813
# Epoch 28/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.2650 - accuracy: 0.8958 - val_loss: 0.1716 - val_accuracy: 0.9312
# Epoch 29/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.2794 - accuracy: 0.8737 - val_loss: 0.2029 - val_accuracy: 0.9125
# Epoch 30/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.2909 - accuracy: 0.8971 - val_loss: 0.2217 - val_accuracy: 0.9000
# Epoch 31/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.4198 - accuracy: 0.8268 - val_loss: 0.2366 - val_accuracy: 0.9688
# Epoch 32/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.4159 - accuracy: 0.8724 - val_loss: 0.2602 - val_accuracy: 0.9312
# Epoch 33/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.3387 - accuracy: 0.8828 - val_loss: 0.1387 - val_accuracy: 0.9563
# Epoch 34/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.3209 - accuracy: 0.8633 - val_loss: 0.1982 - val_accuracy: 0.9250
# Epoch 35/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.3611 - accuracy: 0.8438 - val_loss: 0.1605 - val_accuracy: 0.9375
# Epoch 36/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.3103 - accuracy: 0.8698 - val_loss: 0.2030 - val_accuracy: 0.9375
# Epoch 37/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.4015 - accuracy: 0.8333 - val_loss: 0.1860 - val_accuracy: 0.9375
# Epoch 38/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.3268 - accuracy: 0.8542 - val_loss: 0.1702 - val_accuracy: 0.8938
# Epoch 39/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.3048 - accuracy: 0.8815 - val_loss: 0.0751 - val_accuracy: 0.9688
# Epoch 40/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.3872 - accuracy: 0.8307 - val_loss: 0.2694 - val_accuracy: 0.9312
# Epoch 41/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.3711 - accuracy: 0.8919 - val_loss: 0.1919 - val_accuracy: 0.9563
# Epoch 42/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.2610 - accuracy: 0.8984 - val_loss: 0.1804 - val_accuracy: 0.9375
# Epoch 43/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.3764 - accuracy: 0.8229 - val_loss: 0.1392 - val_accuracy: 0.9312
# Epoch 44/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1969 - accuracy: 0.9193 - val_loss: 0.1326 - val_accuracy: 0.9438
# Epoch 45/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.2690 - accuracy: 0.8828 - val_loss: 0.1632 - val_accuracy: 0.9375
# Epoch 46/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.3004 - accuracy: 0.8516 - val_loss: 0.1398 - val_accuracy: 0.9312
# Epoch 47/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.2965 - accuracy: 0.8659 - val_loss: 0.0968 - val_accuracy: 0.9438
# Epoch 48/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.2283 - accuracy: 0.8919 - val_loss: 0.1194 - val_accuracy: 0.9438
# Epoch 49/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.3432 - accuracy: 0.8445 - val_loss: 0.1368 - val_accuracy: 0.9563
# Epoch 50/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.2416 - accuracy: 0.9323 - val_loss: 0.1259 - val_accuracy: 0.9375
# Epoch 51/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.2508 - accuracy: 0.8828 - val_loss: 0.0771 - val_accuracy: 0.9688
# Epoch 52/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.2792 - accuracy: 0.8867 - val_loss: 0.0931 - val_accuracy: 0.9812
# Epoch 53/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.2099 - accuracy: 0.9036 - val_loss: 0.1818 - val_accuracy: 0.9750
# Epoch 54/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.3134 - accuracy: 0.8867 - val_loss: 0.0866 - val_accuracy: 0.9563
# Epoch 55/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.2874 - accuracy: 0.8568 - val_loss: 0.1196 - val_accuracy: 0.9563
# Epoch 56/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.2141 - accuracy: 0.9323 - val_loss: 0.1298 - val_accuracy: 0.9500
# Epoch 57/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1584 - accuracy: 0.9635 - val_loss: 0.0780 - val_accuracy: 0.9563
# Epoch 58/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.3003 - accuracy: 0.8932 - val_loss: 0.0694 - val_accuracy: 0.9750
# Epoch 59/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1433 - accuracy: 0.9440 - val_loss: 0.0872 - val_accuracy: 0.9750
# Epoch 60/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1882 - accuracy: 0.9284 - val_loss: 0.0703 - val_accuracy: 0.9875
# Epoch 61/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1570 - accuracy: 0.9531 - val_loss: 0.0683 - val_accuracy: 0.9688
# Epoch 62/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1860 - accuracy: 0.9245 - val_loss: 0.1157 - val_accuracy: 0.9500
# Epoch 63/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.2604 - accuracy: 0.9258 - val_loss: 0.1043 - val_accuracy: 0.9750
# Epoch 64/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.2206 - accuracy: 0.9258 - val_loss: 0.0542 - val_accuracy: 1.0000
# Epoch 65/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.2329 - accuracy: 0.9206 - val_loss: 0.1887 - val_accuracy: 0.9438
# Epoch 66/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.2199 - accuracy: 0.9089 - val_loss: 0.0457 - val_accuracy: 1.0000
# Epoch 67/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.3229 - accuracy: 0.8581 - val_loss: 0.0767 - val_accuracy: 0.9625
# Epoch 68/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1638 - accuracy: 0.9336 - val_loss: 0.1505 - val_accuracy: 0.9375
# Epoch 69/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.3059 - accuracy: 0.8406 - val_loss: 0.0819 - val_accuracy: 0.9625
# Epoch 70/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.2555 - accuracy: 0.9023 - val_loss: 0.1328 - val_accuracy: 0.9812
# Epoch 71/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.2509 - accuracy: 0.9284 - val_loss: 0.0945 - val_accuracy: 0.9812
# Epoch 72/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.3260 - accuracy: 0.9206 - val_loss: 0.1192 - val_accuracy: 0.9500
# Epoch 73/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1511 - accuracy: 0.9193 - val_loss: 0.1283 - val_accuracy: 0.9500
# Epoch 74/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.2158 - accuracy: 0.9206 - val_loss: 0.0555 - val_accuracy: 0.9812
# Epoch 75/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.2874 - accuracy: 0.8932 - val_loss: 0.0689 - val_accuracy: 0.9875
# Epoch 76/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.2157 - accuracy: 0.9128 - val_loss: 0.0627 - val_accuracy: 0.9812
# Epoch 77/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1744 - accuracy: 0.9688 - val_loss: 0.0891 - val_accuracy: 0.9563
# Epoch 78/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1993 - accuracy: 0.9062 - val_loss: 0.0315 - val_accuracy: 0.9875
# Epoch 79/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1299 - accuracy: 0.9688 - val_loss: 0.0366 - val_accuracy: 0.9937
# Epoch 80/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.1539 - accuracy: 0.9440 - val_loss: 0.0534 - val_accuracy: 0.9750
# Epoch 81/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1999 - accuracy: 0.9252 - val_loss: 0.1144 - val_accuracy: 0.9563
# Epoch 82/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1565 - accuracy: 0.9622 - val_loss: 0.0357 - val_accuracy: 0.9875
# Epoch 83/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.1439 - accuracy: 0.9453 - val_loss: 0.0783 - val_accuracy: 0.9688
# Epoch 84/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.0576 - accuracy: 1.0000 - val_loss: 0.0569 - val_accuracy: 0.9750
# Epoch 85/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.3044 - accuracy: 0.9076 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 86/100
# 3/3 [==============================] - 3s 1s/step - loss: 0.0641 - accuracy: 0.9892 - val_loss: 0.0286 - val_accuracy: 0.9937
# Epoch 87/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1610 - accuracy: 0.9336 - val_loss: 0.0689 - val_accuracy: 0.9750
# Epoch 88/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1737 - accuracy: 0.9193 - val_loss: 0.0732 - val_accuracy: 0.9812
# Epoch 89/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.0904 - accuracy: 0.9727 - val_loss: 0.0421 - val_accuracy: 0.9812
# Epoch 90/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1260 - accuracy: 0.9635 - val_loss: 0.0215 - val_accuracy: 0.9875
# Epoch 91/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1441 - accuracy: 0.9453 - val_loss: 0.0823 - val_accuracy: 0.9812
# Epoch 92/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.1442 - accuracy: 0.9596 - val_loss: 0.0178 - val_accuracy: 1.0000
# Epoch 93/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.2102 - accuracy: 0.9128 - val_loss: 0.0235 - val_accuracy: 0.9812
# Epoch 94/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1017 - accuracy: 0.9626 - val_loss: 0.0692 - val_accuracy: 0.9875
# Epoch 95/100
# 3/3 [==============================] - 5s 2s/step - loss: 0.1655 - accuracy: 0.9375 - val_loss: 0.0437 - val_accuracy: 0.9937
# Epoch 96/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.2165 - accuracy: 0.8932 - val_loss: 0.0593 - val_accuracy: 0.9875
# Epoch 97/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1740 - accuracy: 0.9154 - val_loss: 0.1363 - val_accuracy: 0.9563
# Epoch 98/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.0796 - accuracy: 0.9648 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 99/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.0880 - accuracy: 0.9857 - val_loss: 0.0306 - val_accuracy: 0.9750
# Epoch 100/100
# 3/3 [==============================] - 4s 2s/step - loss: 0.1598 - accuracy: 0.9375 - val_loss: 0.0124 - val_accuracy: 0.9937
# 39
# 50

# %% [markdown]
# # **Training VS Validation**

# %%
import matplotlib.pyplot as plt
def plot_acc_loss(results, epochs):
 acc = results.history['accuracy']
 loss = results.history['loss']
 val_acc = results.history['val_accuracy']
 val_loss = results.history['val_loss']
 plt.figure(figsize=(25, 10))
 plt.subplot(121)
 plt.plot(range(1,epochs), acc[1:], label='Train_acc')
 plt.plot(range(1,epochs), val_acc[1:], label='Test_acc')
 plt.title('Accuracy over ' + str(epochs) + ' Epochs', size=15)
 plt.legend()
 plt.grid(True)
 plt.subplot(122)
 plt.plot(range(1,epochs), loss[1:], label='Train_loss')
 plt.plot(range(1,epochs), val_loss[1:], label='Test_loss')
 plt.title('Loss over ' + str(epochs) +  ' Epochs', size=15)
 plt.legend()
 plt.grid(True)
 plt.show()
 
plot_acc_loss(results, 100)

# %% [markdown]
# # **Predictions**

# %%
import numpy as np
from keras.preprocessing import image

print(training_set.class_indices)
# Out:
# {'covid': 0, 'non': 1}

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Test Image path
imagePath = "/content/drive/MyDrive/DeepLearningPorject/data_set/check/Khela/test/covid/1-s2.0-S0140673620303706-fx1_lrg.jpg"

img=mpimg.imread(imagePath)
imgplot = plt.imshow(img)

test_image = image.load_img(imagePath, target_size = (256, 256))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = classifier.predict(test_image)

if result[0][0] == 1:
    prediction = 'normal'
else:
    prediction = 'covid'

    
plt=plt.title('Prediction is  '+ prediction )
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

imagePath = "/content/drive/MyDrive/DeepLearningPorject/data_set/check/Khela/test/non/patient00599-study1-view1_frontal.jpg"

img=mpimg.imread(imagePath)
imgplot = plt.imshow(img)

test_image = image.load_img(imagePath, target_size = (256, 256))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = classifier.predict(test_image)

if result[0][0] == 1:
    prediction = 'normal'
else:
    prediction = 'covid'

    

plt=plt.title('Prediction is  '+ prediction )
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
loss, accuracy = classifier.evaluate(test_set, steps = validation_steps)

print("Loss: {:.2f}".format(loss))
print("Accuracy: {:.2f}".format(accuracy))
print("---------------------------")
# Out:
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0574 - accuracy: 0.9896
# Loss: 0.06
# Accuracy: 0.99
# ---------------------------

# %%
tf.saved_model.save(classifier, './models/classifier/1')
# Out:
# INFO:tensorflow:Assets written to: ./models/classifier/1/assets
