# %% [markdown]
# <a href="https://colab.research.google.com/github/yej117/Cloud_Segmentation_Deep_Learning/blob/main/dataset_Seb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load the dataset

# %% [markdown]
#  Mount your Google Drive to the kernel.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/DL_project/kaggle/data/
# Out:
# /content/drive/.shortcut-targets-by-id/1RpWol6vm8TFuJ9p0mkSUtbZHKsT3GtOy/DL_project/kaggle/data

# %%
# !ls
# Out:
# train	  train_hq.zip	train_masks.csv      train_masks.zip
# train_hq  train_masks	train_masks.csv.zip  train.zip

# %%
# %cd  /content/drive/MyDrive/DL_project/kaggle/data/train/
#!ls
# Out:
# /content/drive/.shortcut-targets-by-id/1RpWol6vm8TFuJ9p0mkSUtbZHKsT3GtOy/DL_project/kaggle/data/train

# %%
import os

# Directory with our training car pictures
train_car_dir = os.path.join('/content/drive/MyDrive/DL_project/kaggle/data/train')

# Directory with our training mask pictures
train_mask_dir = os.path.join('/content/drive/MyDrive/DL_project/kaggle/data/train_masks')

# %%
train_car_names = os.listdir(train_car_dir)
print(train_car_names[:10])

train_mask_names = os.listdir(train_mask_dir)
print(train_mask_names[:10])
# Out:
# ['cf65b1c5e147_04.jpg', 'cf89c3220bc4_09.jpg', 'cf89c3220bc4_02.jpg', 'cf89c3220bc4_16.jpg', 'cf65b1c5e147_11.jpg', 'cf89c3220bc4_15.jpg', 'cf89c3220bc4_05.jpg', 'cf65b1c5e147_16.jpg', 'cf89c3220bc4_12.jpg', 'cf89c3220bc4_07.jpg']
# ['0ee135a3cccc_02_mask.gif', '0eeaf1ff136d_07_mask.gif', '0ee135a3cccc_11_mask.gif', '0ed6904e1004_14_mask.gif', '0ee135a3cccc_05_mask.gif', '0eeaf1ff136d_05_mask.gif', '0ee135a3cccc_01_mask.gif', '0d53224da2b7_13_mask.gif', '0ed6904e1004_15_mask.gif', '0d1a9caf4350_02_mask.gif']

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Parameters for our graph; we'll output images in a 4x4 configuration
nrows = 4
ncols = 5

# Index for iterating over images
pic_index = 0

# Set up matplotlib fig, and size it to fit 4x4 pics
fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 3)
pic_index = 0
#pic_index += 1
next_car_pix = [os.path.join(train_car_dir, fname) 
                for fname in train_car_names[pic_index:pic_index+10]]
next_mask_pix = [os.path.join(train_mask_dir, fname) 
                for fname in train_mask_names[pic_index:pic_index+10]]

for i, img_path in enumerate(next_car_pix+next_mask_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()
